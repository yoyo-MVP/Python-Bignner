# %%
! pip install face_recognition
# Out:
# Requirement already satisfied: face_recognition in c:\users\asus\anaconda3\lib\site-packages (1.3.0)
# Requirement already satisfied: face-recognition-models>=0.3.0 in c:\users\asus\anaconda3\lib\site-packages (from face_recognition) (0.3.0)
# Requirement already satisfied: Click>=6.0 in c:\users\asus\anaconda3\lib\site-packages (from face_recognition) (8.1.7)
# Requirement already satisfied: dlib>=19.7 in c:\users\asus\anaconda3\lib\site-packages (from face_recognition) (19.24.6)
# Requirement already satisfied: numpy in c:\users\asus\anaconda3\lib\site-packages (from face_recognition) (1.26.4)
# Requirement already satisfied: Pillow in c:\users\asus\anaconda3\lib\site-packages (from face_recognition) (11.0.0)
# Requirement already satisfied: colorama in c:\users\asus\anaconda3\lib\site-packages (from Click>=6.0->face_recognition) (0.4.6)

# %%
from matplotlib import pyplot as plt

# %%
import face_recognition
from PIL import Image,ImageDraw

# %%
image_of_Fa=face_recognition.load_image_file('c:/face1.jpg')
Fa_face_encoding=face_recognition.face_encodings(image_of_Fa)[0]
plt.imshow(image_of_Fa)

# %%
image_of_Esther=face_recognition.load_image_file("c:/face2.jpg")
Esther_face_encoding=face_recognition.face_encodings(image_of_Esther)[0]
plt.imshow(image_of_Esther)

# %%
image_of_Winston=face_recognition.load_image_file("c:/face3.jpg")
Winston_face_encoding=face_recognition.face_encodings(image_of_Winston)[0]
plt.imshow(image_of_Winston)

# %%
known_face_encodings=[Fa_face_encoding,Winston_face_encoding]
known_face_names=["Fa","Winston"]

# %%
test_image=face_recognition.load_image_file("c:/leader.jpg")
plt.imshow(test_image)

# %%
face_locations=face_recognition.face_locations(test_image)
face_encodings=face_recognition.face_encodings(test_image,face_locations)

# %%
pil_image=Image.fromarray(test_image)
draw=ImageDraw.Draw(pil_image)

# %%
for(top,right,bottom,left),face_encoding in zip(face_locations,face_encodings):
    matches=face_recognition.compare_faces(known_face_encodings,face_encoding)
    name="unknown Person"
    if True in matches:
        first_match_index=matches.index(True)
        name=known_face_names[first_match_index]
    if True in matches:
            second_match_index=matches.index(True)
            name=known_face_names[second_match_index]
            draw.rectangle(((left,top),(right,bottom)),outline=(0,0,0))
            text_width,text_height=draw.textsize(name)
            draw.rectangle(((left,bottom-text_height-8),(right,bottom)),fil=(0,0,255),outline=(0,0,0))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[111], line 11
#       9 name=known_face_names[second_match_index]
#      10 draw.rectangle(((left,top),(right,bottom)),outline=(0,0,0))
# ---> 11 text_width,text_height=draw.textsize(name)
#      12 draw.rectangle(((left,bottom-text_height-8),(right,bottom)),fil=(0,0,255),outline=(0,0,0))
#
# AttributeError: 'ImageDraw' object has no attribute 'textsize'

# %%
pil_image.show()
pil_image.save("c:/picture/identify.jpg")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[69], line 2
#       1 pil_image.show()
# ----> 2 pil_image.save("c:/picture/identify.jpg")
#
# File ~\anaconda3\Lib\site-packages\PIL\Image.py:2600, in Image.save(self, fp, format, **params)
#    2598         fp = builtins.open(filename, "r+b")
#    2599     else:
# -> 2600         fp = builtins.open(filename, "w+b")
#    2601 else:
#    2602     fp = cast(IO[bytes], fp)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:\\picture\\identify.jpg'
